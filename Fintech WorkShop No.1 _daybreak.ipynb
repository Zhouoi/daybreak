# %% [markdown]
# # 金融科技第一次实验 Fintech WorkShop No.1
# ## 实验目标：熟悉Git、GitHub、Markdown和Jupyter Notebook
# ## 实验内容
# + git [官方网站](https://git-scm.com/doc)
# + GitHub [官方网站](https://github.com/)
# + Markdown [CheatSheet](https://github.com/adam-p/markdown-here/wiki/Markdown-Cheatsheet)
# + Jupyter Notebook [CheatSheet](https://res.cloudinary.com/dyd911kmh/image/upload/v1676302533/Marketing/Blog/Jupyterlab_Cheat_Sheet.pdf)

# %% [markdown]
# ### 1. GIT和Github
# 因为我们一直在不断进步，所以我们也不断修改我们的文档和代码。：）
# GIT能够帮助我们更好地进行版本管理。 “版本控制”，也称为版本控制，源代码控制 或软件配置管理（SCM），是 **存储和管理文档、代码的更改信息**。
#
# 跟踪并重现工作的每一步 在软件世界中：它被称为版本控制！
#
# （优秀的）版本控制工具给你带来了什么？
#
# 安心（备份） 自由（探索性分支） 协作（同步）
#
# #### GIT常用命令和用法
# + **安装git** 参见官网安装文档 [link](https://git-scm.com/book/zh/v2/%E8%B5%B7%E6%AD%A5-%E5%AE%89%E8%A3%85-Git
# )
#
# + **在本地创建存储库repo** *(<font color=red>请补齐操作步骤</font>)*
#
#     1.设置git全局用户名
#
#     `git config --global user.name "Zhouoi" //用户名`
#
#     `git config --global user.email "464005430@qq.com" //邮箱`
#
#     2.初始化当前文件夹为git仓库
#
#     `mkdir mynewproject //mkdir是用来创建一个目录`
#
#     `cd mynewproject/ //cd是目录导航的命令`
#
#     `git init //git初始化`
#
#     3.设置git当前仓库用户名
#
#     `git config user.name "DayBreak" //用户名`
#
#     `git config user.email "464005430@qq.com" //邮箱地址`
#
#     4.检查当前用户名设置
#
#     `git config --list //查看git的设置情况`
#
#
# + **在本地创建文件、添加文件和修改文件时的git操作** *(<font color=red>请补齐操作步骤</font>)*
#
#     1.创建本文档workshop.ipynb
#
#     `vi workshop.ipynb //创建新的文档`
#
#     2.添加和确认提交此文件
#
#     `git add workshop.ipynb //添加`
#
#     `git commit //提交该文件`
#
#     3.修改文件后再次确认提交
#
#     `git add workshop.ipynb`
#
#     `git commit -m"update workshop.ipynb" //修改`
#
#     4.查看当前仓库状态
#
#     `git status //显示git仓库的状态`
#
#
# + **创建远程仓库[ref](https://docs.github.com/zh/get-started/importing-your-projects-to-github/importing-source-code-to-github/adding-locally-hosted-code-to-github)** *(<font color=red>请补齐操作步骤</font>)*
#
#      1.在github上创建账号并获取ssh-key
#
#      `$ ssh-keygen -t rsa -C "464005430@qq.com" //生成ssh`
#
#      `cat ~/.ssh/id_rsa.pub //找到生成Key值的目录,前往.ssh目录查看对应的公钥，再在GitHub设置中添加新ssh`
#
#      2.在github上创建一个没有readme、许可协议和git ignore文件的新存储库
#
#      3.在上一步创建的本地仓库中添加远程仓库地址（github）
#
#      `git init //初始化`
#
#      `git remote add origin git@github.com:Zhouoi/daybreak.git //本地和远程建立联系`
#
#      4.将本地仓库的更改推送到github中
#
#      `git add . //暂存 `
#
#      `git commit -m "first commit" //提交到本地 `
#
#      `git push origin master //提交 `
#
#
# + **获取他人（组长）的远程仓库到本地并完成更改后提交** *(<font color=red>请补齐操作步骤</font>)*
#
#     `git clone git@github.com:Zhouoi/daybreak.git //将远程仓库克隆到本地`
#
#     `git add . //提交当前文件夹所有的文件`
#
#     `git add [路径]`
#
#     `git commit -m "first commit"`
#
#     `git push origin master //将本地提交推送到远程仓库`
#
#
# + **组长合并他人的提交** *(<font color=red>请补齐操作步骤</font>)*
#
#     `git checkout master`
#
#     `git merge cate`
#
#     `git push`

# %% [markdown]
# ### 2. Markdown常用命令和用法
# #### 常用语法
#
# (*<font color=red>请补齐操作步骤</font>*)
#
# + 标题 （这是xxx的自我介绍标题）
# + 粗体、斜体和~~删除线~~ （我的**兴趣爱好**， 我的*擅长*， 我改进了~~哪些我不喜欢的内容~~）
# + 有序列表和无序列表
# + [超链接](https://www.swufe.edu.cn/)
# + 插入图像
# + 插入`代码`以突出显示
# + 插入整块引用
# >这是我最近最喜欢的一句话，是由某某某所讲
# + 插入视频
# ---
# #### 完成个人介绍，使用Markdown完成

# %% [markdown]
# # 这是李晨鋆的自我介绍标题
#
# + 我的兴趣是**吹竹笛**，我擅长*学习*，我改进了~~人际交往方式~~
#
#
# 1. 有
# 2. 序
# 3. 列
# 4. 表
#
#
# * 无
# * 序
# * 列
# * 表
#
#
# + [中国慕课](https://www.icourse163.org/)
#
#
# + 图像
#
# ![yaya](https://5b0988e595225.cdn.sohucs.com/images/20180820/be44467b5db2463bbd2abb485809a649.jpg)
#
#
# + 代码 `print("Python yyds")`
#
# + 视频
# <iframe height="400" width="600" src="//https://www.bilibili.com/video/BV1ZE411s774?t=25.0" scrolling="no" border="0" frameborder="no" framespacing="0" allowfullscreen="true"> </iframe>
# >

# %% [markdown]
# # 这是周翔宇的自我介绍标题
#
# + 我的兴趣是**弹钢琴**，我擅长*睡觉*，我改进了~~游泳技术~~
#
#
# 1. 有
# 2. 序
# 3. 列
# 4. 表
#
#
# + 无
# + 序
# + 列
# + 表
#
#
# + [超链接](https://www.swufe.edu.cn/)
#
#
# + 图像
#
#
# ![baidu logo](https://img-blog.csdnimg.cn/img_convert/0aaf388e02c6bd9beaec2cefff89c858.png)
#
#
# + 代码`print("hello world!")`
#
# >毋意，毋必，毋固，毋我。
# > >这是我最近最喜欢的一句话，来自《论语》
#
# + 视频
#
# <iframe height="400" width="600" src="//player.bilibili.com/player.html?aid=49775093&cid=87150521&page=1" scrolling="no" border="0" frameborder="no" framespacing="0" allowfullscreen="true"> </iframe>

# %% [markdown]
# # 这是张雯萱的自我介绍
#
# 我**爱逛微博**，我*擅长买卡*，我改进了~~混吃等死的心态~~
#
# 1. 有趣
# 2. 无趣
# 3. 呵呵
#
#
# + 批发
# + 倒卖
# + 崩溃
#
# [百度](https://www.baidu.com/)
#
# ![seulgi](https://p2.ifengimg.com/2018_35/5DC358F2F2EB45EDC3CDF86DDE11787AEDCAE129_w619_h396.jpg)
#
# At the command prompt, type`sos`
#
# >祝大家天天开心
# >>这是我最近最喜欢的一句话，是我自己所讲
#
# <video src="https://www.bilibili.com/video/BV1sx4y157vP?t=1.3"></video><iframe height=600 width=800 src="https://www.bilibili.com/video/BV1sx4y157vP?t=1.3">

# %% [markdown]
# # 这是陈佳妮的自我介绍标题
#
# + 我的兴趣是**做美甲**，我擅长*打工*，我改进了~~在洗澡的时候唱歌~~
#
#
# 1. 有
# 2. 序
# 3. 列
# 4. 表
#
#
# + 无
# + 序
# + 列
# + 表
#
#
# + [东方财富网](https://www.eastmoney.com/)
#
#
# + 图像
#
#
# ![apple](https://img0.baidu.com/it/u=242767209,2541342896&fm=253&fmt=auto&app=138&f=JPEG?w=889&h=500)
#
#
# + 代码`print("1+1！=2")`
#
# >真正的英雄主义是在看清生活的本质之后，依然热爱它
# > >这是我最近最喜欢的一句话，是由罗曼罗兰所讲
#
# + 视频
# <iframe height=498 width=510 src="https://www.bilibili.com/video/BV15s4y1f7d3?t=27.1">

# %% [markdown]
# # 这是李心乐的自我介绍标题
#
# + 我的兴趣是**睡觉**，我擅长*睡觉*，我改进了~~上课睡觉~~
#
#
# 1. 有
# 2. 序
# 3. 列
# 4. 表
#
#
# + 无
# + 序
# + 列
# + 表
#
#
# + [超链接](http://paper.people.com.cn/rmrb/html/2023-03/01/nbs.D110000renmrb_01.htm)
#
#
# + 图像
#
# ![swufe](https://edu.cnr.cn/pdtj/yw/20150106/W020150106401748311539.png)
#
#
# + 代码`print("SWUFE HELLO!")`
#
# >但行好事，莫问前程。
# > >这是我最近最喜欢的一句话，来自《增广贤文》
#
# + 视频
#
# <iframe height="400" width="600" src="// https://www.bilibili.com/video/BV1gL41177sr/?share_source=copy_web&vd_source=5bc56e7d46c1081b90fa87b05808c444" scrolling="no" border="0" frameborder="no" framespacing="0" allowfullscreen="true"> </iframe>

# %% [markdown]
# # 这是郑睿姮的自我介绍标题
#
# + 我的兴趣是**散步与唱歌**，我擅长*摸鱼*，我改进了~~烹饪技术~~
#
#
# 1. 有
# 2. 序
# 3. 列
# 4. 表
#
#
# + 无
# + 序
# + 列
# + 表
#
#
# + [超链接](https://www.cnki.net/)
#
#
# + 图像
#
#
# ![dog](https://www.ssfiction.com/wp-content/uploads/2020/08/20200805_5f2b1669e9a24.jpg)
#
#
# + 代码
#
# `ip=input("请输入数字：")
# ip=int(ip)
# ans=0
# while ip!=0:
#     ans*=10
#     ans+=int(ip%10)
#     ip=int((ip-ip%10)/10)
# print(ans)`
#
# >且视他人之疑目如盏盏鬼火，大胆地去走你的夜路。
# > >这是我最近最喜欢的一句话，是史铁生说的
#
# + 视频
#
# <iframe src="/ayer.bilibili.com/player.html?aid=540867524&bvid=BV1ei4y1s7pU&cid=195803856&page=1" scrolling="no" border="0" frameborder="no" framespacing="0" allowfullscreen="true"> </iframe>

# %% [markdown]
# # 这是吴宣萱的自我介绍标题
#
# + 我的兴趣是**听音乐**，我擅长*吃美食*，我改进了~~每天熬夜熬到深夜才睡觉的习惯~~
#
#
# 1. 有
# 2. 序
# 3. 列
# 4. 表
#
#
# + 无
# + 序
# + 列
# + 表
#
#
# + [github超链接](https://www.github.edu.cn/)
#
#
# + 图像
#
#
# ![玫瑰图片](https://scpic.chinaz.net/files/pic/pic9/201806/bpic7031.jpg)
#
#
# + 代码`print("我好想躺平")`
#
# >不要等待，时机永远不会恰到好处。。
# > >这是我最近最喜欢的一句话，来自拿破仑.希尔
#
# + 视频
#
# <iframe height=498 width=510 src="https://www.bilibili.com/video/BV1QL411J7gm?t=3.4">

# %% [markdown]
# ---
# #### 请各自补充组员的基本信息
#
#
# | 姓名 | 学号 | 专业及年级 | 小组代号  |
# | ---------- | ---------- | ---------- | ----------|
# | 李晨鋆 | 42112170 | 2021CFA | 破晓 |
# | 周翔宇 | 42119009 | 2021CFA | 破晓 |
# | 吴宣萱 | 42120006 | 2021CFA | 破晓 |
# | 张雯萱 | 42106004 | 2021CFA | 破晓 |
# | 陈佳妮 | 42137005 | 2021CFA | 破晓 |
# | 李心乐 | 42112133 | 2021CFA | 破晓 |
# | 郑睿姮 | 42126016 | 2021CFA | 破晓 |

# %% [markdown]
# ## 3.Jupyter的基本用法

# %% [markdown]
# ## 4.数学公式（选学）

# %% [markdown]
# + 二项式定理
#
# $$(x+y)^n=\sum_{k=0}^{n}\begin{pmatrix}n\\k\\ \end{pmatrix}x^{n-k}y^k$$

# %% [markdown]
# + 指数函数
#
# $$e^x=\lim_{n \to \infty}(1+\frac{x}{n})^n$$

# %% [markdown]
# + 柯西不等式
#
# $$\left(\sum_{k=1}^{n}a_kb_k\right)^2\leq\left(\sum_{k=1}^{n}a_k^2\right)\left(\sum_{k=1}^{n}b_k^2\right)$$

# %% [markdown]
# + 贝叶斯定理
#
# $$P(A|B)=\frac{P(B|A)P(A)}{P(B)}$$

# %% [markdown]
# ## 5.附录

# %% [markdown]
# 1. 在你认为合适的地方新建文件夹，右击选择git hash
#
# 2. 设置git全局用户名
#
#   `git config --global user.name "Zhouoi" //改成你的用户名`
#
#   `git config --global user.email "464005430@qq.com" //你的邮箱`
#
# 3. 设置git当前仓库用户名
#
#   `git config user.name "DayBreak" //改成你的用户名`
#
#   `git config user.email "464005430@qq.com" //邮箱地址`
#
# 4. 在github上创建账号并获取ssh-key
#
#   `$ ssh-keygen -t rsa -C "464005430@qq.com" //生成ssh`
#
#    注意：此处会让你选择保存地址，设置密码等，建议连点三次回车
#
#   `cat ~/.ssh/id_rsa.pub //找到生成Key值的目录,前往.ssh目录查看对应的公钥，再在GitHub设置中添加新ssh`
#
# 5. 将daybreak中的文件fork到自己的仓库
#
# 6. 在上一步的仓库中添加远程仓库地址（github）
#
#   `git init //初始化`
#
#   `git remote add origin git@github.com:Zhouoi/daybreak.git //上一步提到的自己的仓库，点击clone,再点击ssh就可以找到这个远程地址`
#
# 7. clone你仓库中的文件
#
#  `git clone git@github.com:Zhouoi/daybreak.git //同上，是你自己的仓库地址`
#
#   此时，在你的新建文件夹中就会出现下载好的文件
#
# 8. 在juptyter中修改并保存
#
# 9. 新建文件夹中右击选择git hash
#
#   `git add . //修改后提交当前文件夹所有的文件`
#
#   `git commit -m "xxx " //可以换成你的名字`
#
#   `git push //将本地提交推送到远程仓库`
#
# 10. 此时你仓库中的文件已完成替换
#
# 11. 来到小组daybreak仓库，点击pull request，create new pr,选择蓝色的fork文字，就可以将你fork的文件上传pr
#
# 12. 发送请求
